# %%
# PART 0: Downloading the Data

import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
import scikit_posthocs as sp 

from scipy.stats import levene, kruskal

# I put the data in a folder named data/
# The data is too large to upload to github, so this is only local. 
path_0 = "data/exported_new_results_nih_funded_gene_annotations_clean-000000000000.csv"
path_1 = "data/exported_new_results_nih_funded_gene_annotations_clean-000000000001.csv"

raw_data_0 = pd.read_csv(path_0)
raw_data_1 = pd.read_csv(path_1)

# %%
# Just looking at the parts of the data
print(raw_data_0.columns)
print(raw_data_0.shape)
print(raw_data_1.columns)
print(raw_data_1.shape)
# Out:
# Index(['DB_Object_Symbol', 'DB_Object_Name', 'DB_Object_ID', 'DB_Object_Type',
#        'DB_Object_Synonym', 'GO_ID', 'Aspect', 'Qualifier', 'Evidence_Code',
#        'pmid_extracted', 'PMID', 'DB_Reference', 'PROJECT_NUMBER',
#        'APPLICATION_ID', 'PROJECT_TITLE', 'PI_NAMEs', 'ORG_NAME', 'ORG_STATE',
#        'ORG_COUNTRY', 'TOTAL_COST', 'DIRECT_COST_AMT', 'INDIRECT_COST_AMT',
#        'FY', 'PROJECT_START', 'PROJECT_END', 'ACTIVITY', 'FULL_PROJECT_NUM',
#        'PROJECT_TERMS', 'PHR', 'annotation_date', 'Assigned_By', 'Taxon'],
#       dtype='object')
# (197441, 32)
# Index(['DB_Object_Symbol', 'DB_Object_Name', 'DB_Object_ID', 'DB_Object_Type',
#        'DB_Object_Synonym', 'GO_ID', 'Aspect', 'Qualifier', 'Evidence_Code',
#        'pmid_extracted', 'PMID', 'DB_Reference', 'PROJECT_NUMBER',
#        'APPLICATION_ID', 'PROJECT_TITLE', 'PI_NAMEs', 'ORG_NAME', 'ORG_STATE',
#        'ORG_COUNTRY', 'TOTAL_COST', 'DIRECT_COST_AMT', 'INDIRECT_COST_AMT',
#        'FY', 'PROJECT_START', 'PROJECT_END', 'ACTIVITY', 'FULL_PROJECT_NUM',
#        'PROJECT_TERMS', 'PHR', 'annotation_date', 'Assigned_By', 'Taxon'],
#       dtype='object')
# (197561, 32)

# %%
# PART 1: Pre-Processing the Data

# Concatenate the two datafiles together, check that it worked. 
data = pd.concat((raw_data_0, raw_data_1), ignore_index=True)
data.shape
# Out:
# (395002, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395002 entries, 0 to 395001
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DB_Object_Symbol   395002 non-null  object
#  1   DB_Object_Name     395002 non-null  object
#  2   DB_Object_ID       395002 non-null  object
#  3   DB_Object_Type     395002 non-null  object
#  4   DB_Object_Synonym  394840 non-null  object
#  5   GO_ID              395002 non-null  object
#  6   Aspect             395002 non-null  object
#  7   Qualifier          395002 non-null  object
#  8   Evidence_Code      395002 non-null  object
#  9   pmid_extracted     395002 non-null  int64
#  10  PMID               395002 non-null  int64
#  11  DB_Reference       395002 non-null  object
#  12  PROJECT_NUMBER     395002 non-null  object
#  13  APPLICATION_ID     395002 non-null  int64
#  14  PROJECT_TITLE      395002 non-null  object
#  15  PI_NAMEs           395002 non-null  object
#  16  ORG_NAME           395002 non-null  object
#  17  ORG_STATE          394743 non-null  object
#  18  ORG_COUNTRY        395002 non-null  object
#  19  TOTAL_COST         394994 non-null  float64
#  20  DIRECT_COST_AMT    394997 non-null  float64
#  21  INDIRECT_COST_AMT  388596 non-null  float64
#  22  FY                 395002 non-null  int64
#  23  PROJECT_START      395002 non-null  object
#  24  PROJECT_END        395002 non-null  object
#  25  ACTIVITY           395002 non-null  object
#  26  FULL_PROJECT_NUM   395002 non-null  object
#  27  PROJECT_TERMS      330747 non-null  object
#  28  PHR                393160 non-null  object
#  29  annotation_date    395002 non-null  int64
#  30  Assigned_By        395002 non-null  object
#  31  Taxon              395002 non-null  object
# dtypes: float64(3), int64(5), object(24)
# memory usage: 96.4+ MB

# %%
print(data['ORG_STATE'].unique())
print(data['ORG_COUNTRY'].unique())
# Out:
# ['NE' 'MA' 'KS' 'HI' 'BC' 'OH' 'MD' 'WA' 'WI' 'NY' 'PA' 'TX' 'GA' 'SC'
#  'NC' 'DC' 'NJ' 'FL' 'TN' 'MO' 'CA' 'IA' 'VT' 'CT' 'MN' 'IL' 'RI' 'AR'
#  'VA' 'MI' 'OR' 'AZ' 'CO' 'AL' 'KY' 'OK' 'MT' 'ME' 'IN' 'ND' nan 'NV' 'LA'
#  'NH' 'UT' 'MS' 'NM' 'WV' 'WY' 'ON' 'PQ' 'DE' 'QC' 'SD']
# ['UNITED STATES' 'CANADA' 'COLOMBIA' 'UNITED KINGDOM' 'BELGIUM' 'ISRAEL'
#  'SPAIN' 'AUSTRALIA' 'CHINA' 'BRAZIL']

# %%
data['Taxon'].unique()
# Out:
#   DB_Object_Symbol                                     DB_Object_Name  \
# 0            Pink1  Serine/threonine-protein kinase PINK1, mitocho...
# 1            Pink1  Serine/threonine-protein kinase PINK1, mitocho...
# 2              Nf1                         Neurofibromin 1, isoform B
# 3             Cirl                                   Latrophilin Cirl
# 4              DAT              Sodium-dependent dopamine transporter
# 5              Nf1                         Neurofibromin 1, isoform B
# 6             Cirl                                   Latrophilin Cirl
# 7              Nf1                         Neurofibromin 1, isoform B
# 8             Cirl                                   Latrophilin Cirl
# 9              Nf1                         Neurofibromin 1, isoform B
#
#   DB_Object_ID DB_Object_Type  \
# 0       B5DFG1        protein
# 1       B5DFG1        protein
# 2       Q9VBJ2        protein
# 3       A1Z7G7        protein
# 4       Q7K4Y6        protein
# 5       Q9VBJ2        protein
# 6       A1Z7G7        protein
# 7       Q9VBJ2        protein
# 8       A1Z7G7        protein
# 9       Q9VBJ2        protein
#
#                                    DB_Object_Synonym       GO_ID Aspect  \
# 0                                              Pink1  GO:0031999      P
# 1                                              Pink1  GO:0000266      P
# 2  Nf1|Dmel\CG8318|FBpp0084326|NF-1|NF1|Nf-1|dNF1...  GO:0008344      P
# 3                                        Cirl|CG8639  GO:0008344      P
# 4                                     DAT|fmn|CG8380  GO:0008344      P
# 5  Nf1|Dmel\CG8318|FBpp0084326|NF-1|NF1|Nf-1|dNF1...  GO:0008344      P
# 6                                        Cirl|CG8639  GO:0008344      P
# 7  Nf1|Dmel\CG8318|FBpp0084326|NF-1|NF1|Nf-1|dNF1...  GO:0008344      P
# 8                                        Cirl|CG8639  GO:0008344      P
# 9  Nf1|Dmel\CG8318|FBpp0084326|NF-1|NF1|Nf-1|dNF1...  GO:0008344      P
#
#      Qualifier Evidence_Code  pmid_extracted  ...    FY PROJECT_START  \
# 0  involved_in           HMP        25421206  ...  2014    2005-02-10
# 1  involved_in           HMP        25421206  ...  2014    2005-02-10
# 2  involved_in           IMP        25962619  ...  2016    2008-09-01
# 3  involved_in           IMP        25962619  ...  2013    2008-09-01
# 4  involved_in           IMP        25962619  ...  2014    2008-09-01
# 5  involved_in           IMP        25962619  ...  2014    2008-09-01
# 6  involved_in           IMP        25962619  ...  2014    2008-09-01
# 7  involved_in           IMP        25962619  ...  2015    2008-09-01
# 8  involved_in           IMP        25962619  ...  2015    2008-09-01
# 9  involved_in           IMP        25962619  ...  2017    2008-09-01
#
#   PROJECT_END  ACTIVITY FULL_PROJECT_NUM  \
# 0  2016-03-31       R01  5R01MH073490-11
# 1  2016-03-31       R01  5R01MH073490-11
# 2  2020-07-31       R01  2R01GM084947-09
# 3  2016-07-31       R01  5R01GM084947-06
# 4  2016-07-31       R01  5R01GM084947-07
# 5  2016-07-31       R01  5R01GM084947-07
# 6  2016-07-31       R01  5R01GM084947-07
# 7  2016-07-31       R01  5R01GM084947-08
# 8  2016-07-31       R01  5R01GM084947-08
# 9  2020-07-31       R01  5R01GM084947-10
#
#                                        PROJECT_TERMS  \
# 0  Address;AIDS neuropathy;Autophagocytosis;Brain...
# 1  Address;AIDS neuropathy;Autophagocytosis;Brain...
# 2  Address;base;Cells;Clustered Regularly Intersp...
# 3                                                NaN
# 4  Address;base;Biological;Biological Assay;Biolo...
# 5  Address;base;Biological;Biological Assay;Biolo...
# 6  Address;base;Biological;Biological Assay;Biolo...
# 7  Address;base;Biological;Biological Assay;Biolo...
# 8  Address;base;Biological;Biological Assay;Biolo...
# 9  Address;base;Cells;Clustered Regularly Intersp...
#
#                                                  PHR annotation_date  \
# 0   While treatment for HIV infection has improve...        20210212
# 1   While treatment for HIV infection has improve...        20210212
# 2  PROJECT NARRATIVE This project is seeking cont...        20160811
# 3       This project is seeking continued support...        20160811
# 4       This project is seeking continued support...        20160811
# 5       This project is seeking continued support...        20160811
# 6       This project is seeking continued support...        20160811
# 7  This project is seeking continued support for ...        20160811
# 8  This project is seeking continued support for ...        20160811
# 9  PROJECT NARRATIVE This project is seeking cont...        20160811
#
#   Assigned_By        Taxon
# 0         RGD  taxon:10116
# 1         RGD  taxon:10116
# 2     FlyBase   taxon:7227
# 3     FlyBase   taxon:7227
# 4     FlyBase   taxon:7227
# 5     FlyBase   taxon:7227
# 6     FlyBase   taxon:7227
# 7     FlyBase   taxon:7227
# 8     FlyBase   taxon:7227
# 9     FlyBase   taxon:7227
#
# [10 rows x 32 columns]
